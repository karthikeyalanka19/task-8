# %% [markdown]
# # **NLP Filter Resume**

# %% [markdown]
# # **Task-3**
# **Create an application that should be used by the HR Team to filter the resume based on the Skills**
#
#
# #![screenshot-1-.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **INSTALLING & IMPORTING THE DEPENDENCIES**

# %%
#!pip install pdfminer.six
#!pip install python-docx

# %%
#!pip install docx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#pip install pyresparser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
nltk.download('stopwords')
from pyresparser import ResumeParser
import os
from docx import Document 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ##**File Format should be in .txt, .docx or .pdf only**

# %%
filed=input()
# Out:
# /content/RESUME pdf.pdf

# %% [markdown]
# **Filtering resume based on skills**

# %%
try:
  doc=Document()
  with open(filed,"r") as file:
    doc.add_paragraph(file.read())
  doc.save("text.docx")
  data=ResumeParser("text.docx").get_extracted_data()
  print(data["skills"])
except:
  data=ResumeParser(filed).get_extracted_data()
  print(data["skills"])
# Out:
# ['Cloud', 'Microsoft excel', 'Standardization', 'Pivot', 'Research', 'Seaborn', 'Pandas', 'Flex', 'Procurement', 'Css', 'Presentation', 'Matplotlib', 'C', 'Mysql', 'Html', 'Data collection', 'Sql', 'Negotiation', 'Programming', 'English', 'Operations management', 'Segmentation', 'Database', 'Algorithms', 'Statistics', 'Design', 'Spyder', 'German', 'Ux', 'Python', 'Email', 'Aws', 'International', 'Ui', 'Data quality', 'Numpy', 'Operations', 'Mining', 'Excel', 'Analytics', 'Metrics', 'Oracle', 'Engineering', 'Analysis', 'Training', 'Supply chain']

# %% [markdown]
# **Main paramters seperation from pyresparser**

# %%
data
# Out:
# {'college_name': None,
#  'company_names': ['Amazon'],
#  'degree': ['Master Data Science'],
#  'designation': ['SENIOR ANALYST / DATA', 'SENIOR ANALYST'],
#  'email': 'santhoshramesh2010@gmail.com',
#  'experience': ['Dec 2021 -',
#   'SENIOR ANALYST',
#   'Present',
#   'Flex, Chennai, India',
#   'Global Procurement and supply chain division @ Flex Global',
#   'Business Services.',
#   'Direct Procurement, Procure to pay, Materials',
#   'management, Supply and demand management, Shortage',
#   'mitigation, Allocation validation, Supplier Negotiation,',
#   'Return Material Authorization, Excess and Obsolete',
#   'management , Accounts Payable challenges resolution,',
#   'Intercompany stock transfer , Premium Freight',
#   'Authorization, Operations Management, Tra\x00ic',
#   'recommendation, End to End supply chain for assigned',
#   'commodities @ Flextronics Manufacturing US Site.'],
#  'mobile_number': '9080119287',
#  'name': 'SANTHOSH RAMESH',
#  'no_of_pages': 2,
# ...

# %%
from pdfminer.high_level import extract_text

def extract_text_from_pdf(pdf_path):
    return extract_text(pdf_path)

if __name__ == '__main__':
    print(extract_text_from_pdf('RESUME pdf.pdf'))
# Out:
# .
#
# SANTHOSH
# RAMESH
# SENIOR ANALYST / DATA
#
# SCIENTIST
#
# Personal Info
#
# Address
#
# Chennai, Tamilnadu, India
#
# Phone
#
# +919080119287
#
# Email
#
# santhoshramesh2010@gmail.com
#
# Skills
#
# Machine Learning Algorithm
#
# Linear regression,
#
# Ridge & Lasso Regression,
#
# Logistic Regression, KNN,
#
# K means Clustering, Naive Bayes,
#
# SVM,  Decision Trees,
#
# Random Forest, Adaptive boosting,
#
# Gradient boosting Optimization
#
# Python Libraries
#
# Numpy, Pandas, Matplotlib,
#
# Seaborn, scikit-learn, dash
#
# Programming
#
# Python, C#
#
# NLP
#
# Data Science integrated learner who is experienced in training with data
# handling techniques using python libraries and connecting with cloud and SQL
#
# Database. I have a good grasp of probability and stats with data visualization. I
#
# also have over 6 months of experience as a Senior Procurement Analyst for US
#
# clients.
#
# Work Experience
#
# Dec 2021 -
#
# SENIOR ANALYST
#
# Present
#
# ...

# %%
import docx2txt
import nltk

# %% [markdown]
# **Skills based on datascience resume**

# %% [markdown]
# # Based on skills available in the resume.

# %% [markdown]
# Stop words removal, Punctuation removal, Word tokenization

# %%
SKILLS_DB = [
             'feature enginnering',
             'python',
    'machine learning',
    'data science',
    'nlp',
    'feature enginnering'
    'web development'
    'python'
]
 
def extract_text_from_pdf(pdf_path):
    return extract_text(pdf_path)
 
def extract_text_from_docx(docx_path):
    txt = docx2txt.process(docx_path)
    if txt:
        return txt.replace('\t', ' ')
    return None
 
 
def extract_skills(input_text):
    stop_words = set(nltk.corpus.stopwords.words('english'))
    word_tokens = nltk.tokenize.word_tokenize(input_text)
 
    # remove the stop words
    filtered_tokens = [w for w in word_tokens if w not in stop_words]
 
    # remove the punctuation
    filtered_tokens = [w for w in word_tokens if w.isalpha()]
 
    # generate bigrams and trigrams (such as artificial intelligence)
    bigrams_trigrams = list(map(' '.join, nltk.everygrams(filtered_tokens, 2, 3)))
 
    # we create a set to keep the results in.
    found_skills = set()
 
    # we search for each token in our skills database
    for token in filtered_tokens:
        if token.lower() in SKILLS_DB:
            found_skills.add(token)
 
    # we search for each bigram and trigram in our skills database
    for ngram in bigrams_trigrams:
        if ngram.lower() in SKILLS_DB:
            found_skills.add(ngram)
 
    return found_skills
 
 
if __name__ == '__main__':
    text = extract_text_from_pdf('/content/RESUME pdf.pdf')
    skills = list(extract_skills(text))
    skill = ["Data Science",'NLP']
    
    check =  all(item in skills for item in skill)

    if check is True:
      print("Your Resume sorted for further round")
    else:
      print("Your Resume not move to next round")
# Out:
# Your Resume sorted for further round

# %% [markdown]
# # Based on skill not available on the resume

# %%
# you may read the database from a csv file or some other database
SKILLS_DB = [
             'feature enginnering',
             'python',
    'machine learning',
    'data science',
    'nlp',
    'feature enginnering'
    'web development'
    'python'
]

# %%
def extract_text_from_pdf(pdf_path):
    return extract_text(pdf_path)
 
def extract_text_from_docx(docx_path):
    txt = docx2txt.process(docx_path)
    if txt:
        return txt.replace('\t', ' ')
    return None
 
 
def extract_skills(input_text):
    stop_words = set(nltk.corpus.stopwords.words('english'))
    word_tokens = nltk.tokenize.word_tokenize(input_text)
 
    # remove the stop words
    filtered_tokens = [w for w in word_tokens if w not in stop_words]
 
    # remove the punctuation
    filtered_tokens = [w for w in word_tokens if w.isalpha()]
 
    # generate bigrams and trigrams (such as artificial intelligence)
    bigrams_trigrams = list(map(' '.join, nltk.everygrams(filtered_tokens, 2, 3)))
 
    # we create a set to keep the results in.
    found_skills = set()
 
    # we search for each token in our skills database
    for token in filtered_tokens:
        if token.lower() in SKILLS_DB:
            found_skills.add(token)
 
    # we search for each bigram and trigram in our skills database
    for ngram in bigrams_trigrams:
        if ngram.lower() in SKILLS_DB:
            found_skills.add(ngram)
 
    return found_skills
 
 
if __name__ == '__main__':
    text = extract_text_from_pdf('/content/RESUME pdf.pdf')
    skills = list(extract_skills(text))
    skill = ["Data science",'NLP']
    
    check =  all(item in skills for item in skill)

    if check is True:
      print("Your Resume sorted for further round")
    else:
      print("Your Resume not move to next round")
# Out:
# Your Resume not move to next round
